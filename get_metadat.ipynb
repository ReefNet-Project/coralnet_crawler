# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('sources.csv')
df = df[['Source', 'Valid']]
df.head(15)
df_excluded = df.loc[df['Valid'] != 'yes']
df_excluded.head(25)
# Out:
#                                                 Source Valid
# 2           19.20.21.22 South coast intertidal surveys    no
# 6                                5 Mile Seasonal Study   FEW
# 23                                     Chieh-Jhen Chen   FEW
# 26                                             CPP_ROV    no
# 36                          CVCE Bocas Del Toro Survey  yes
# 37                                  Derwent seagrasses    no
# 38                                     Diadema surveys   FEW
# 42                                        G_Walls_StFX    no
# 43                 Halophila in the North Beach, Eilat    no
# 45                                             HLO GSL    no
# 47                           Israel Monitoring program   FEW
# 50              Koloa Landing 2022-23 Random Transects  yes
# 52                Laura - Intertidal winter surveys 14    no
# 63                                 MarineGEO Hong Kong    no
# 73                                                MBON    no
# 74                                 MBON P2P (AMPs.ARG)    no
# 75                                       MBON_AR_CO_EC    no
# 89                                        NOAA ESD CAU    no
# 93                                        NTL_SeaGrass    no
# 98                      Port Hawkesbury Deployment 1.0    no
# 100  Rocky Reef Biodiversity Survey: Punta Pardelas...    no
# 103                                   SEAMOBB-3_France    no
# 112                            TUMCA Ecological Survey  yes
# 116                                              Vavau  yes
# 121                              West_Hawaii_eDNA_2022  yes

# %%
home_url = 'https://coralnet.ucsd.edu/source/about/'
# grab the source code
r = requests.get(home_url)
